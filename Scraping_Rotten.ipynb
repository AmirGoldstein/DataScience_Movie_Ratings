# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup
import re
import time

# %% [markdown]
# # Scraping data from rotten as a table

# %%
url="https://www.rottentomatoes.com/top/bestofrt/"
response = requests.get(url)

# %%
rotten = pd.read_html(str(url))[2]
rotten = rotten[['Title','RatingTomatometer','Rank']]
rotten
# Out:
#                                Title RatingTomatometer   Rank
# 0               Black Panther (2018)               96%    1.0
# 1           Avengers: Endgame (2019)               94%    2.0
# 2                          Us (2019)               93%    3.0
# 3                 Toy Story 4 (2019)               97%    4.0
# 4            The Wizard of Oz (1939)               98%    5.0
# ..                               ...               ...    ...
# 95  Won't You Be My Neighbor? (2018)               97%   96.0
# 96                  Chinatown (1974)               99%   97.0
# 97         Lawrence of Arabia (1962)               98%   98.0
# 98        I Am Not Your Negro (2017)               99%   99.0
# 99                Rear Window (1954)               99%  100.0
#
# [100 rows x 3 columns]

# %% [markdown]
# # Setting up title & year into arrays from the data we scraped, using regex

# %%
title = []
year = []
pattern = "(.*)\s\s*\((\d*)"
for d in rotten['Title']:
    rottenMovies = re.search(pattern,d)
    title.append(rottenMovies.group(1))
    year.append(rottenMovies.group(2))

# %%
rotten['Year'] = year
rotten['Title'] = title
rotten.columns = ['Title', 'Tomatometer', 'Rotten rank', 'Year']
rotten
# Out:
#                         Title Tomatometer  Rotten rank  Year
# 0               Black Panther         96%          1.0  2018
# 1           Avengers: Endgame         94%          2.0  2019
# 2                          Us         93%          3.0  2019
# 3                 Toy Story 4         97%          4.0  2019
# 4            The Wizard of Oz         98%          5.0  1939
# ..                        ...         ...          ...   ...
# 95  Won't You Be My Neighbor?         97%         96.0  2018
# 96                  Chinatown         99%         97.0  1974
# 97         Lawrence of Arabia         98%         98.0  1962
# 98        I Am Not Your Negro         99%         99.0  2017
# 99                Rear Window         99%        100.0  1954
#
# [100 rows x 4 columns]

# %% [markdown]
# # Creating a list of relevant URLs for rotten into an array for further use

# %%
url_list = []
rotten_url = "https://www.rottentomatoes.com"
pattern = "\/m.*"
soup = BeautifulSoup(response.content, 'lxml')
soup = soup.find('table', {'class': 'table'})
urls = [a['href'] for a in soup.find_all('a', {'class': 'unstyled articleLink'})]
for movie in urls:
    url_list.append(rotten_url + re.search(pattern,movie).group())
url_list
# Out:
# ['https://www.rottentomatoes.com/m/black_panther_2018',
#  'https://www.rottentomatoes.com/m/avengers_endgame',
#  'https://www.rottentomatoes.com/m/us_2019',
#  'https://www.rottentomatoes.com/m/toy_story_4',
#  'https://www.rottentomatoes.com/m/the_wizard_of_oz_1939',
#  'https://www.rottentomatoes.com/m/mission_impossible_fallout',
#  'https://www.rottentomatoes.com/m/lady_bird',
#  'https://www.rottentomatoes.com/m/citizen_kane',
#  'https://www.rottentomatoes.com/m/the_irishman',
#  'https://www.rottentomatoes.com/m/blackkklansman',
#  'https://www.rottentomatoes.com/m/the_cabinet_of_dr_caligari',
#  'https://www.rottentomatoes.com/m/get_out',
#  'https://www.rottentomatoes.com/m/1003707-casablanca',
#  'https://www.rottentomatoes.com/m/spider_man_into_the_spider_verse',
#  'https://www.rottentomatoes.com/m/mad_max_fury_road',
#  'https://www.rottentomatoes.com/m/nosferatu',
#  'https://www.rottentomatoes.com/m/moonlight_2016',
#  'https://www.rottentomatoes.com/m/booksmart',
#  'https://www.rottentomatoes.com/m/a_star_is_born_2018',
#  'https://www.rottentomatoes.com/m/wonder_woman_2017',
#  'https://www.rottentomatoes.com/m/the_farewell_2019',
#  'https://www.rottentomatoes.com/m/inside_out_2015',
#  'https://www.rottentomatoes.com/m/a_quiet_place_2018',
#  'https://www.rottentomatoes.com/m/modern_times',
#  'https://www.rottentomatoes.com/m/the_third_man',
#  'https://www.rottentomatoes.com/m/eighth_grade',
#  'https://www.rottentomatoes.com/m/it_happened_one_night',
#  'https://www.rottentomatoes.com/m/roma_2018',
#  'https://www.rottentomatoes.com/m/dunkirk_2017',
#  'https://www.rottentomatoes.com/m/la_grande_illusion',
#  'https://www.rottentomatoes.com/m/coco_2017',
#  'https://www.rottentomatoes.com/m/godfather',
#  'https://www.rottentomatoes.com/m/spotlight_2015',
#  'https://www.rottentomatoes.com/m/selma',
#  'https://www.rottentomatoes.com/m/1048445-snow_white_and_the_seven_dwarfs',
#  'https://www.rottentomatoes.com/m/thor_ragnarok_2017',
#  'https://www.rottentomatoes.com/m/singin_in_the_rain',
#  'https://www.rottentomatoes.com/m/the_shape_of_water_2017',
#  'https://www.rottentomatoes.com/m/arrival_2016',
#  'https://www.rottentomatoes.com/m/1000626-all_about_eve',
#  'https://www.rottentomatoes.com/m/spider_man_far_from_home',
#  'https://www.rottentomatoes.com/m/logan_2017',
#  'https://www.rottentomatoes.com/m/et_the_extraterrestrial',
#  'https://www.rottentomatoes.com/m/call_me_by_your_name',
#  'https://www.rottentomatoes.com/m/the_big_sick',
#  'https://www.rottentomatoes.com/m/the_favourite_2018',
#  'https://www.rottentomatoes.com/m/incredibles_2',
#  'https://www.rottentomatoes.com/m/star_wars_the_last_jedi',
#  'https://www.rottentomatoes.com/m/1011615-king_kong',
#  'https://www.rottentomatoes.com/m/1018688-shadow_of_a_doubt',
#  'https://www.rottentomatoes.com/m/bride_of_frankenstein',
#  'https://www.rottentomatoes.com/m/paddington_2',
#  'https://www.rottentomatoes.com/m/star_wars_episode_vii_the_force_awakens',
#  'https://www.rottentomatoes.com/m/1012007-laura',
#  'https://www.rottentomatoes.com/m/1000355-adventures_of_robin_hood',
#  'https://www.rottentomatoes.com/m/gravity_2013',
#  'https://www.rottentomatoes.com/m/once_upon_a_time_in_hollywood',
#  'https://www.rottentomatoes.com/m/boyhood',
#  'https://www.rottentomatoes.com/m/alien',
#  'https://www.rottentomatoes.com/m/leave_no_trace',
#  'https://www.rottentomatoes.com/m/manchester_by_the_sea',
#  'https://www.rottentomatoes.com/m/argo_2012',
#  'https://www.rottentomatoes.com/m/la_la_land',
#  'https://www.rottentomatoes.com/m/12_years_a_slave',
#  'https://www.rottentomatoes.com/m/zootopia',
#  'https://www.rottentomatoes.com/m/the_battle_of_algiers',
#  'https://www.rottentomatoes.com/m/1013139-maltese_falcon',
#  'https://www.rottentomatoes.com/m/top_hat',
#  'https://www.rottentomatoes.com/m/beatles_a_hard_days_night',
#  'https://www.rottentomatoes.com/m/war_for_the_planet_of_the_apes',
#  'https://www.rottentomatoes.com/m/psycho',
#  'https://www.rottentomatoes.com/m/the_florida_project',
#  'https://www.rottentomatoes.com/m/philadelphia_story',
#  'https://www.rottentomatoes.com/m/widows_2018',
#  'https://www.rottentomatoes.com/m/1013775-metropolis',
#  'https://www.rottentomatoes.com/m/spider_man_homecoming',
#  'https://www.rottentomatoes.com/m/1012928-m',
#  'https://www.rottentomatoes.com/m/1017293-rebecca',
#  'https://www.rottentomatoes.com/m/night_of_the_hunter',
#  'https://www.rottentomatoes.com/m/north-by-northwest',
#  'https://www.rottentomatoes.com/m/seven_samurai_1956',
#  'https://www.rottentomatoes.com/m/baby_driver',
#  'https://www.rottentomatoes.com/m/three_billboards_outside_ebbing_missouri',
#  'https://www.rottentomatoes.com/m/shoplifters',
#  'https://www.rottentomatoes.com/m/shazam',
#  'https://www.rottentomatoes.com/m/sunset_boulevard',
#  'https://www.rottentomatoes.com/m/bicycle_thieves',
#  'https://www.rottentomatoes.com/m/hell_or_high_water',
#  'https://www.rottentomatoes.com/m/1021749-touch_of_evil',
#  'https://www.rottentomatoes.com/m/up',
#  'https://www.rottentomatoes.com/m/pinocchio_1940',
#  'https://www.rottentomatoes.com/m/jaws',
#  'https://www.rottentomatoes.com/m/toy_story_2',
#  'https://www.rottentomatoes.com/m/captain_america_civil_war',
#  'https://www.rottentomatoes.com/m/1020333-streetcar_named_desire',
#  'https://www.rottentomatoes.com/m/wont_you_be_my_neighbor',
#  'https://www.rottentomatoes.com/m/chinatown',
#  'https://www.rottentomatoes.com/m/lawrence_of_arabia',
#  'https://www.rottentomatoes.com/m/i_am_not_your_negro',
#  'https://www.rottentomatoes.com/m/1017289-rear_window']

# %% [markdown]
# # Moving through all URLs in order to scrape Genre and Avg Rating

# %%
avg_rating = []
movie_genre = []
javascript_regex = 'tomatometerAllCritics":{"avgScore":(\d.?\d*)\,'
for i in url_list:
    response1 = ''
    while response1 == '':
        try:
            response1 = requests.get(i)
            break
        except:
            print("Connection refused by the server..")
            print("Sleeping for 5 seconds")
            time.sleep(5)
            print("continue...")
            continue
    
    soup1 = BeautifulSoup(response1.content, 'lxml')
    movie_genre.append(soup1.find_all('div', {'class': 'meta-value'})[1].text.replace(",","").split())
    scripts = soup1.find('script',{'type' : 'text/javascript'}).get_text()
    score = re.search(javascript_regex, scripts)
    if score is None:
        print("No score in: " + i)
        avg_rating.append(None)
    else:
        print("Getting score from: " + i)
        avg_rating.append(score.group(1))
# Out:
# Getting score from: https://www.rottentomatoes.com/m/black_panther_2018
# Getting score from: https://www.rottentomatoes.com/m/avengers_endgame
# Getting score from: https://www.rottentomatoes.com/m/us_2019
# Getting score from: https://www.rottentomatoes.com/m/toy_story_4
# Getting score from: https://www.rottentomatoes.com/m/the_wizard_of_oz_1939
# Getting score from: https://www.rottentomatoes.com/m/mission_impossible_fallout
# Getting score from: https://www.rottentomatoes.com/m/lady_bird
# Getting score from: https://www.rottentomatoes.com/m/citizen_kane
# Getting score from: https://www.rottentomatoes.com/m/the_irishman
# Getting score from: https://www.rottentomatoes.com/m/blackkklansman
# Getting score from: https://www.rottentomatoes.com/m/the_cabinet_of_dr_caligari
# Getting score from: https://www.rottentomatoes.com/m/get_out
# Getting score from: https://www.rottentomatoes.com/m/1003707-casablanca
# Getting score from: https://www.rottentomatoes.com/m/spider_man_into_the_spider_verse
# Getting score from: https://www.rottentomatoes.com/m/mad_max_fury_road
# Getting score from: https://www.rottentomatoes.com/m/nosferatu
# Getting score from: https://www.rottentomatoes.com/m/moonlight_2016
# Getting score from: https://www.rottentomatoes.com/m/booksmart
# Getting score from: https://www.rottentomatoes.com/m/a_star_is_born_2018
# Getting score from: https://www.rottentomatoes.com/m/wonder_woman_2017
# Getting score from: https://www.rottentomatoes.com/m/the_farewell_2019
# Getting score from: https://www.rottentomatoes.com/m/inside_out_2015
# Getting score from: https://www.rottentomatoes.com/m/a_quiet_place_2018
# Getting score from: https://www.rottentomatoes.com/m/modern_times
# Getting score from: https://www.rottentomatoes.com/m/the_third_man
# Getting score from: https://www.rottentomatoes.com/m/eighth_grade
# Getting score from: https://www.rottentomatoes.com/m/it_happened_one_night
# Getting score from: https://www.rottentomatoes.com/m/roma_2018
# Getting score from: https://www.rottentomatoes.com/m/dunkirk_2017
# Getting score from: https://www.rottentomatoes.com/m/la_grande_illusion
# Getting score from: https://www.rottentomatoes.com/m/coco_2017
# Getting score from: https://www.rottentomatoes.com/m/godfather
# Getting score from: https://www.rottentomatoes.com/m/spotlight_2015
# Getting score from: https://www.rottentomatoes.com/m/selma
# Getting score from: https://www.rottentomatoes.com/m/1048445-snow_white_and_the_seven_dwarfs
# Getting score from: https://www.rottentomatoes.com/m/thor_ragnarok_2017
# Getting score from: https://www.rottentomatoes.com/m/singin_in_the_rain
# Getting score from: https://www.rottentomatoes.com/m/the_shape_of_water_2017
# Getting score from: https://www.rottentomatoes.com/m/arrival_2016
# Getting score from: https://www.rottentomatoes.com/m/1000626-all_about_eve
# Getting score from: https://www.rottentomatoes.com/m/spider_man_far_from_home
# Getting score from: https://www.rottentomatoes.com/m/logan_2017
# Getting score from: https://www.rottentomatoes.com/m/et_the_extraterrestrial
# Getting score from: https://www.rottentomatoes.com/m/call_me_by_your_name
# Getting score from: https://www.rottentomatoes.com/m/the_big_sick
# Getting score from: https://www.rottentomatoes.com/m/the_favourite_2018
# Getting score from: https://www.rottentomatoes.com/m/incredibles_2
# Getting score from: https://www.rottentomatoes.com/m/star_wars_the_last_jedi
# Getting score from: https://www.rottentomatoes.com/m/1011615-king_kong
# Getting score from: https://www.rottentomatoes.com/m/1018688-shadow_of_a_doubt
# Getting score from: https://www.rottentomatoes.com/m/bride_of_frankenstein
# Getting score from: https://www.rottentomatoes.com/m/paddington_2
# Getting score from: https://www.rottentomatoes.com/m/star_wars_episode_vii_the_force_awakens
# Getting score from: https://www.rottentomatoes.com/m/1012007-laura
# Getting score from: https://www.rottentomatoes.com/m/1000355-adventures_of_robin_hood
# Getting score from: https://www.rottentomatoes.com/m/gravity_2013
# Getting score from: https://www.rottentomatoes.com/m/once_upon_a_time_in_hollywood
# Getting score from: https://www.rottentomatoes.com/m/boyhood
# Getting score from: https://www.rottentomatoes.com/m/alien
# Getting score from: https://www.rottentomatoes.com/m/leave_no_trace
# Getting score from: https://www.rottentomatoes.com/m/manchester_by_the_sea
# Getting score from: https://www.rottentomatoes.com/m/argo_2012
# Getting score from: https://www.rottentomatoes.com/m/la_la_land
# Getting score from: https://www.rottentomatoes.com/m/12_years_a_slave
# Getting score from: https://www.rottentomatoes.com/m/zootopia
# Getting score from: https://www.rottentomatoes.com/m/the_battle_of_algiers
# Getting score from: https://www.rottentomatoes.com/m/1013139-maltese_falcon
# Getting score from: https://www.rottentomatoes.com/m/top_hat
# Getting score from: https://www.rottentomatoes.com/m/beatles_a_hard_days_night
# Getting score from: https://www.rottentomatoes.com/m/war_for_the_planet_of_the_apes
# Getting score from: https://www.rottentomatoes.com/m/psycho
# Getting score from: https://www.rottentomatoes.com/m/the_florida_project
# Getting score from: https://www.rottentomatoes.com/m/philadelphia_story
# Getting score from: https://www.rottentomatoes.com/m/widows_2018
# Getting score from: https://www.rottentomatoes.com/m/1013775-metropolis
# Getting score from: https://www.rottentomatoes.com/m/spider_man_homecoming
# Getting score from: https://www.rottentomatoes.com/m/1012928-m
# Getting score from: https://www.rottentomatoes.com/m/1017293-rebecca
# Getting score from: https://www.rottentomatoes.com/m/night_of_the_hunter
# Getting score from: https://www.rottentomatoes.com/m/north-by-northwest
# Getting score from: https://www.rottentomatoes.com/m/seven_samurai_1956
# Getting score from: https://www.rottentomatoes.com/m/baby_driver
# Getting score from: https://www.rottentomatoes.com/m/three_billboards_outside_ebbing_missouri
# Getting score from: https://www.rottentomatoes.com/m/shoplifters
# Getting score from: https://www.rottentomatoes.com/m/shazam
# Getting score from: https://www.rottentomatoes.com/m/sunset_boulevard
# Getting score from: https://www.rottentomatoes.com/m/bicycle_thieves
# Getting score from: https://www.rottentomatoes.com/m/hell_or_high_water
# Getting score from: https://www.rottentomatoes.com/m/1021749-touch_of_evil
# Getting score from: https://www.rottentomatoes.com/m/up
# Getting score from: https://www.rottentomatoes.com/m/pinocchio_1940
# Getting score from: https://www.rottentomatoes.com/m/jaws
# Getting score from: https://www.rottentomatoes.com/m/toy_story_2
# Getting score from: https://www.rottentomatoes.com/m/captain_america_civil_war
# Getting score from: https://www.rottentomatoes.com/m/1020333-streetcar_named_desire
# Getting score from: https://www.rottentomatoes.com/m/wont_you_be_my_neighbor
# Getting score from: https://www.rottentomatoes.com/m/chinatown
# Getting score from: https://www.rottentomatoes.com/m/lawrence_of_arabia
# Getting score from: https://www.rottentomatoes.com/m/i_am_not_your_negro
# Getting score from: https://www.rottentomatoes.com/m/1017289-rear_window

# %%
genre = []
for g in movie_genre:
    if g[0]=='Classics':
        genre.append(g[1])
    else:
        genre.append(g[0])

# %%
rotten['Critic Rating'] = avg_rating
rotten['Genre'] = genre

# %% [markdown]
# # Data Cleaning & Convertions

# %%
rotten['Tomatometer'] = rotten['Tomatometer'].str.replace('%','').astype('float64')
rotten['Tomatometer'] = rotten['Tomatometer']/10.0
rotten['Genre'] = rotten['Genre'].str.replace(",","")
rotten['Critic Rating'] = rotten['Critic Rating'].astype('float')
rotten['Difference'] = rotten['Tomatometer'] - rotten['Critic Rating']

# %%
rotten
# Out:
#                         Title  Tomatometer  Rotten rank  Year  Critic Rating  \
# 0               Black Panther          9.6          1.0  2018           8.28
# 1           Avengers: Endgame          9.4          2.0  2019           8.22
# 2                          Us          9.3          3.0  2019           7.95
# 3                 Toy Story 4          9.7          4.0  2019           8.36
# 4            The Wizard of Oz          9.8          5.0  1939           9.40
# ..                        ...          ...          ...   ...            ...
# 95  Won't You Be My Neighbor?          9.7         96.0  2018           8.72
# 96                  Chinatown          9.9         97.0  1974           9.34
# 97         Lawrence of Arabia          9.8         98.0  1962           9.27
# 98        I Am Not Your Negro          9.9         99.0  2017           8.89
# 99                Rear Window          9.9        100.0  1954           9.16
#
#           Genre  Difference
# 0        Action        1.32
# 1        Action        1.18
# 2        Horror        1.35
# 3     Animation        1.34
# 4          Kids        0.40
# ..          ...         ...
# 95  Documentary        0.98
# 96        Drama        0.56
# 97       Action        0.53
# 98  Documentary        1.01
# 99        Drama        0.74
#
# [100 rows x 7 columns]

# %%
rotten['Rotten rank']= rotten['Rotten rank'].astype('int64')
rotten['Year']= rotten['Year'].astype('int64')

rotten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          100 non-null    object
#  1   Tomatometer    100 non-null    float64
#  2   Rotten rank    100 non-null    int64
#  3   Year           100 non-null    int64
#  4   Critic Rating  100 non-null    float64
#  5   Genre          100 non-null    object
#  6   Difference     100 non-null    float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %% [markdown]
# # Saving the dataframe we made into a csv file to load

# %%
rotten.to_csv('rottenData.csv')
